# %%
import pandas as pd
import numpy as np


salary_data = pd.read_csv("salary_data_states.csv")
salary_data.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# ...

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167278 entries, 0 to 167277
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CASE_NUMBER                     167278 non-null  object
#  1   CASE_STATUS                     167278 non-null  object
#  2   CASE_RECEIVED_DATE              167278 non-null  object
#  3   DECISION_DATE                   167278 non-null  object
#  4   EMPLOYER_NAME                   167278 non-null  object
#  5   PREVAILING_WAGE_SUBMITTED       167278 non-null  float64
#  6   PREVAILING_WAGE_SUBMITTED_UNIT  167278 non-null  object
#  7   PAID_WAGE_SUBMITTED             167278 non-null  float64
#  8   PAID_WAGE_SUBMITTED_UNIT        167278 non-null  object
#  9   JOB_TITLE                       167278 non-null  object
#  10  WORK_CITY                       167275 non-null  object
#  11  EDUCATION_LEVEL_REQUIRED        11093 non-null   object
# ...

# %%
salary_data['COUNTRY_OF_CITIZENSHIP'].value_counts()
# Out:
# INDIA                    6587
# CHINA                    1101
# CANADA                    425
# PHILIPPINES               300
# SOUTH KOREA               269
#                          ...
# SERBIA AND MONTENEGRO       1
# ANTIGUA AND BARBUDA         1
# ICELAND                     1
# CYPRUS                      1
# PARAGUAY                    1
# Name: COUNTRY_OF_CITIZENSHIP, Length: 134, dtype: int64

# %%
#salary_data.groupby(by=[ 'CASE_STATUS', 'COUNTRY_OF_CITIZENSHIP']).agg(len)


citizen = pd.pivot_table(salary_data, 
                         index= 'CASE_STATUS', columns = 'COUNTRY_OF_CITIZENSHIP', aggfunc = 'count')

citizen
# Out:
#                        CASE_NUMBER                                        \
# COUNTRY_OF_CITIZENSHIP     ALBANIA ALGERIA ANTIGUA AND BARBUDA ARGENTINA
# CASE_STATUS
# certified                      1.0     NaN                 1.0      18.0
# certified-expired              4.0     NaN                 NaN      13.0
# denied                         NaN     1.0                 NaN       1.0
# withdrawn                      NaN     NaN                 NaN       2.0
#
#                                                                      \
# COUNTRY_OF_CITIZENSHIP ARMENIA AUSTRALIA AUSTRIA AZERBAIJAN BAHAMAS
# CASE_STATUS
# certified                  4.0      17.0     1.0        NaN     1.0
# certified-expired          1.0      14.0     6.0        2.0     NaN
# denied                     NaN       1.0     NaN        NaN     NaN
# withdrawn                  3.0       2.0     NaN        NaN     NaN
#
#                                                                          \
# ...

# %%
certified_row = citizen.iloc[[0]]
certified_row
# Out:
#                        CASE_NUMBER                                        \
# COUNTRY_OF_CITIZENSHIP     ALBANIA ALGERIA ANTIGUA AND BARBUDA ARGENTINA
# CASE_STATUS
# certified                      1.0     NaN                 1.0      18.0
#
#                                                                      \
# COUNTRY_OF_CITIZENSHIP ARMENIA AUSTRALIA AUSTRIA AZERBAIJAN BAHAMAS
# CASE_STATUS
# certified                  4.0      17.0     1.0        NaN     1.0
#
#                                                                          \
# COUNTRY_OF_CITIZENSHIP BANGLADESH BARBADOS BELARUS BELGIUM BELIZE BENIN
# CASE_STATUS
# certified                    22.0      NaN    20.0     6.0    1.0   1.0
#
#                                                                                \
# COUNTRY_OF_CITIZENSHIP BERMUDA BOLIVIA BOSNIA AND HERZEGOVINA BRAZIL BULGARIA
# CASE_STATUS
# certified                  NaN     1.0                    1.0   40.0     10.0
#
# ...

# %%
highest_cert = (certified_row['CASE_NUMBER'] > 10)

highest_cert
# Out:
# COUNTRY_OF_CITIZENSHIP  ALBANIA  ALGERIA  ANTIGUA AND BARBUDA  ARGENTINA  \
# CASE_STATUS
# certified                 False    False                False       True
#
# COUNTRY_OF_CITIZENSHIP  ARMENIA  AUSTRALIA  AUSTRIA  AZERBAIJAN  BAHAMAS  \
# CASE_STATUS
# certified                 False       True    False       False    False
#
# COUNTRY_OF_CITIZENSHIP  BANGLADESH  BARBADOS  BELARUS  BELGIUM  BELIZE  BENIN  \
# CASE_STATUS
# certified                     True     False     True    False   False  False
#
# COUNTRY_OF_CITIZENSHIP  BERMUDA  BOLIVIA  BOSNIA AND HERZEGOVINA  BRAZIL  \
# CASE_STATUS
# certified                 False    False                   False    True
#
# COUNTRY_OF_CITIZENSHIP  BULGARIA  BURKINA FASO  BURMA (MYANMAR)  CAMEROON  \
# CASE_STATUS
# certified                  False         False            False     False
#
# COUNTRY_OF_CITIZENSHIP  CANADA  CHILE  CHINA  COLOMBIA  COSTA RICA  \
# CASE_STATUS
# ...

# %%
cert = pd.DataFrame(certified_row['CASE_NUMBER'] > 100)

pd.set_option("display.max_rows", None, "display.max_columns", None)
cert

# 50 and over: CANADA, CHINA, FRANCE, GERMANY, INDIA, MEXICO, NEPAL, PHILIPPINES, RUSSIA, SOUTH KOREA, TAIWAN
# 70 and over: CANADA, CHINA, INDIA, MEXICO, PHILIPPINES, SOUTH KOREA, TAIWAN
# 100 and over: CANADA, CHINA, INDIA, MEXICO, SOUTH KOREA
# Out:
# COUNTRY_OF_CITIZENSHIP  ALBANIA  ALGERIA  ANTIGUA AND BARBUDA  ARGENTINA  \
# CASE_STATUS
# certified                 False    False                False      False
#
# COUNTRY_OF_CITIZENSHIP  ARMENIA  AUSTRALIA  AUSTRIA  AZERBAIJAN  BAHAMAS  \
# CASE_STATUS
# certified                 False      False    False       False    False
#
# COUNTRY_OF_CITIZENSHIP  BANGLADESH  BARBADOS  BELARUS  BELGIUM  BELIZE  BENIN  \
# CASE_STATUS
# certified                    False     False    False    False   False  False
#
# COUNTRY_OF_CITIZENSHIP  BERMUDA  BOLIVIA  BOSNIA AND HERZEGOVINA  BRAZIL  \
# CASE_STATUS
# certified                 False    False                   False   False
#
# COUNTRY_OF_CITIZENSHIP  BULGARIA  BURKINA FASO  BURMA (MYANMAR)  CAMEROON  \
# CASE_STATUS
# certified                  False         False            False     False
#
# COUNTRY_OF_CITIZENSHIP  CANADA  CHILE  CHINA  COLOMBIA  COSTA RICA  \
# CASE_STATUS
# ...

# %%
denied_row = citizen.iloc[[2]]
denied_row
# Out:
#                        CASE_NUMBER                                        \
# COUNTRY_OF_CITIZENSHIP     ALBANIA ALGERIA ANTIGUA AND BARBUDA ARGENTINA
# CASE_STATUS
# denied                         NaN     1.0                 NaN       1.0
#
#                                                                      \
# COUNTRY_OF_CITIZENSHIP ARMENIA AUSTRALIA AUSTRIA AZERBAIJAN BAHAMAS
# CASE_STATUS
# denied                     NaN       1.0     NaN        NaN     NaN
#
#                                                                          \
# COUNTRY_OF_CITIZENSHIP BANGLADESH BARBADOS BELARUS BELGIUM BELIZE BENIN
# CASE_STATUS
# denied                        NaN      1.0     1.0     3.0    1.0   NaN
#
#                                                                                \
# COUNTRY_OF_CITIZENSHIP BERMUDA BOLIVIA BOSNIA AND HERZEGOVINA BRAZIL BULGARIA
# CASE_STATUS
# denied                     NaN     NaN                    1.0    1.0      NaN
#
# ...

# %%
highest_dnied = (denied_row['CASE_NUMBER'] > 100)

highest_dnied

#OVER 100: INDIA, PHILIPPINES
# Out:
# COUNTRY_OF_CITIZENSHIP  ALBANIA  ALGERIA  ANTIGUA AND BARBUDA  ARGENTINA  \
# CASE_STATUS
# denied                    False    False                False      False
#
# COUNTRY_OF_CITIZENSHIP  ARMENIA  AUSTRALIA  AUSTRIA  AZERBAIJAN  BAHAMAS  \
# CASE_STATUS
# denied                    False      False    False       False    False
#
# COUNTRY_OF_CITIZENSHIP  BANGLADESH  BARBADOS  BELARUS  BELGIUM  BELIZE  BENIN  \
# CASE_STATUS
# denied                       False     False    False    False   False  False
#
# COUNTRY_OF_CITIZENSHIP  BERMUDA  BOLIVIA  BOSNIA AND HERZEGOVINA  BRAZIL  \
# CASE_STATUS
# denied                    False    False                   False   False
#
# COUNTRY_OF_CITIZENSHIP  BULGARIA  BURKINA FASO  BURMA (MYANMAR)  CAMEROON  \
# CASE_STATUS
# denied                     False         False            False     False
#
# COUNTRY_OF_CITIZENSHIP  CANADA  CHILE  CHINA  COLOMBIA  COSTA RICA  \
# CASE_STATUS
# ...

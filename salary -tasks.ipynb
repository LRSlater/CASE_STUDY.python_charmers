# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary = pd.read_excel("salary_data_states.xlsx")

# %%
salary.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# ...

# %%
salary['JOB_TITLE_SUBGROUP'].unique()
# Out:
# array(['software engineer', 'assistant professor', 'teacher',
#        'business analyst', 'management consultant', 'data analyst',
#        'attorney', 'data scientist'], dtype=object)

# %%
#Do specific sub-types of data-related jobs have higher or lower salaries than others?

avg_salary=salary.groupby(['JOB_TITLE_SUBGROUP'],as_index=False)['PAID_WAGE_PER_YEAR'].mean()
avg_salary.sort_values(by =['PAID_WAGE_PER_YEAR'],ascending= False )
# Out:
#       JOB_TITLE_SUBGROUP  PAID_WAGE_PER_YEAR
# 1               attorney       146413.596714
# 5  management consultant       108251.334662
# 4         data scientist       108021.038248
# 0    assistant professor        94876.713707
# 6      software engineer        92505.303013
# 2       business analyst        71300.079566
# 3           data analyst        70030.078688
# 7                teacher        46039.985507

# %%
#Which companies have the highest salaries for those sub-types?

salary[['JOB_TITLE_SUBGROUP','EMPLOYER_NAME','PAID_WAGE_PER_YEAR']].sort_values(by = ['PAID_WAGE_PER_YEAR'],ascending= False ).groupby(['JOB_TITLE_SUBGROUP']).head(1)
# Out:
#            JOB_TITLE_SUBGROUP                                  EMPLOYER_NAME  \
# 232                  attorney                           WINSTON & STRAWN LLP
# 23290       software engineer                             KPI PARTNERS, INC.
# 87781        business analyst  THE UNIVERSITY OF TEXAS SYSTEM ADMINISTRATION
# 61278     assistant professor                    DIXIE STATE COLLEGE OF UTAH
# 88521            data analyst                                         INTUIT
# 118793                teacher                     FROSTBURG STATE UNIVERSITY
# 14998   management consultant                     CO-CREATION PARTNERS, INC.
# 325            data scientist                                  NETFLIX, INC.
#
#         PAID_WAGE_PER_YEAR
# 232              2500000.0
# 23290            1400000.0
# 87781            1250784.0
# 61278             895000.0
# 88521             746323.0
# 118793            690000.0
# 14998             582400.0
# 325               230000.0

# %%
#Changes with location of the job?

sal_table = pd.pivot_table(salary, 
                       values='PREVAILING_WAGE_PER_YEAR', 
                       index=['JOB_TITLE_SUBGROUP'],
                       columns=['WORK_STATE'], 
                       aggfunc=np.mean)
sal_table
# Out:
# WORK_STATE                   Alabama        Alaska       Arizona  \
# JOB_TITLE_SUBGROUP
# assistant professor     67132.915593  69666.075667  70865.538019
# attorney               108428.581818           NaN  76838.142857
# business analyst        51913.014286  57530.555556  61154.893401
# data analyst            59283.333333           NaN  63209.753333
# data scientist                   NaN           NaN  73558.111111
# management consultant   87818.000000           NaN  75127.288889
# software engineer       66635.552213  61902.400000  70852.987910
# teacher                 40311.111111  44282.616667  34631.098494
#
# WORK_STATE                 Arkansas     California      Colorado  \
# JOB_TITLE_SUBGROUP
# assistant professor    83075.472727   60126.866613  53044.828155
# attorney                        NaN  116417.301709  77609.222222
# business analyst       48765.209804   70997.609220  64975.383756
# data analyst           48981.200000   71625.793509  58624.766667
# ...

# %%
#Changes with location of the job?

avg_salary=salary.groupby(['WORK_STATE_ABBREVIATION'],as_index=False)['PAID_WAGE_PER_YEAR'].mean()

avg_salary.sort_values(by =['PAID_WAGE_PER_YEAR'],ascending= False )
# Out:
#    WORK_STATE_ABBREVIATION  PAID_WAGE_PER_YEAR
# 54                      WV       109426.868925
# 4                       CA       103571.109230
# 52                      WA       102176.679145
# 36                      NY        91601.758915
# 2                       AR        90270.748799
# 1                       AL        87326.275474
# 20                      MA        86610.726739
# 40                      PA        83889.437310
# 7                       DC        81968.360095
# 27                      MS        81950.747813
# 39                      OR        81530.546156
# 17                      KS        81031.775751
# 18                      KY        80146.977145
# 6                       CT        79578.567355
# 21                      MD        79153.982504
# 35                      NV        79152.477377
# 16                      IN        78722.992183
# 13                      IA        78219.470771
# 53                      WI        77728.956490
# ...

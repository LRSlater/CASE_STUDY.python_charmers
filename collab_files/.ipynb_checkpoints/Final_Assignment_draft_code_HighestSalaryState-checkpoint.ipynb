# %%
#What states (of those I am willing to move to) have the highest paying data-related salaries?



import pandas as pd
import numpy as np


salary_data = pd.read_csv("salary_data_states.csv")
salary_data.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 0  I-200-14073-248840      denied          3/14/2014     3/21/2014
# 1       A-15061-55212      denied          3/19/2015     3/19/2015
# 2  I-200-13256-001092      denied          9/13/2013     9/23/2013
# 3  I-200-14087-353657      denied          3/28/2014      4/7/2014
# 4  I-203-14259-128844      denied          9/16/2014     9/23/2014
#
#                                        EMPLOYER_NAME  \
# 0                ADVANCED TECHNOLOGY GROUP USA, INC.
# 1                     SAN FRANCISCO STATE UNIVERSITY
# 2                                    CAROUSEL SCHOOL
# 3  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...
# 4                        SIGNAL SCIENCES CORPORATION
#
#    PREVAILING_WAGE_SUBMITTED PREVAILING_WAGE_SUBMITTED_UNIT  \
# 0                  6217100.0                           year
# 1                  5067600.0                           year
# ...

# %%
 salary_data.groupby('WORK_STATE').get_group('California')
# Out:
#                CASE_NUMBER CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 1            A-15061-55212      denied          3/19/2015     3/19/2015
# 2       I-200-13256-001092      denied          9/13/2013     9/23/2013
# 5       I-200-14092-483272      denied           4/2/2014      4/9/2014
# 6       I-200-13084-487292      denied          3/25/2013     3/28/2013
# 9       I-200-14069-400950      denied          3/10/2014     3/18/2014
# ...                    ...         ...                ...           ...
# 166898  I-201-14106-695111      denied           5/6/2014      5/9/2014
# 166901  I-200-14230-094318   certified          8/18/2014     8/24/2014
# 166902  I-200-13102-619065   certified          4/12/2013     4/18/2013
# 166968       A-14294-17902   certified         11/17/2014     4/30/2015
# 167233  I-203-13177-004887      denied           7/9/2013     7/11/2013
#
#                                  EMPLOYER_NAME  PREVAILING_WAGE_SUBMITTED  \
# ...

# %%
salary_data.groupby('WORK_STATE').count()
# Out:
#                           CASE_NUMBER  CASE_STATUS  CASE_RECEIVED_DATE  \
# WORK_STATE
# Alabama                           559          559                 559
# Alaska                             66           66                  66
# Arizona                          2570         2570                2570
# Arkansas                          558          558                 558
# California                      46782        46782               46782
# Colorado                         1614         1614                1614
# Connecticut                      2023         2023                2023
# Delaware                          874          874                 874
# District of Columbia             1370         1370                1370
# Florida                          4064         4064                4064
# Georgia                          5615         5615                5615
# Guam                               61           61                  61
# ...

# %%
list(salary_data['JOB_TITLE_SUBGROUP'].unique())
# Out:
# ['software engineer',
#  'assistant professor',
#  'teacher',
#  'business analyst',
#  'management consultant',
#  'data analyst',
#  'attorney',
#  'data scientist']

# %%
#grouping data by state and job
salary_data.groupby(by=['WORK_STATE', 'JOB_TITLE_SUBGROUP']).agg(len)
# Out:
#                                   CASE_NUMBER  CASE_STATUS  \
# WORK_STATE JOB_TITLE_SUBGROUP
# Alabama    assistant professor            354          354
#            attorney                        11           11
#            business analyst                56           56
#            data analyst                     6            6
#            management consultant            1            1
# ...                                       ...          ...
# Wyoming    assistant professor             26           26
#            attorney                         1            1
#            business analyst                 6            6
#            software engineer                6            6
#            teacher                          6            6
#
#                                   CASE_RECEIVED_DATE  DECISION_DATE  \
# WORK_STATE JOB_TITLE_SUBGROUP
# Alabama    assistant professor                   354            354
# ...

# %%
#mean salary for each state and job

sal_table = pd.pivot_table(salary_data, 
                       values='PAID_WAGE_PER_YEAR', 
                       index=['JOB_TITLE_SUBGROUP'],
                       columns=['WORK_STATE'], 
                       aggfunc=np.mean)
sal_table
# Out:
# WORK_STATE                   Alabama        Alaska        Arizona  \
# JOB_TITLE_SUBGROUP
# assistant professor     93636.291130  89011.044667  117570.082236
# attorney               117450.763636           NaN   94298.971429
# business analyst        57515.321429  64563.017778   69833.877411
# data analyst            69803.333333           NaN   70150.240000
# data scientist                   NaN           NaN  105117.728889
# management consultant   99008.000000           NaN   95005.333333
# software engineer       83930.774836  71515.133333   76000.455701
# teacher                 44215.777778  51013.416667   38216.975323
#
# WORK_STATE                  Arkansas     California      Colorado  \
# JOB_TITLE_SUBGROUP
# assistant professor    134444.617091   91066.240533  89944.517670
# attorney                         NaN  144759.907607  88119.111111
# business analyst        58604.467255   76568.124680  70245.483249
# ...

# %%
sal_table = pd.pivot_table(salary_data, 
                       values='PREVAILING_WAGE_PER_YEAR', 
                       index=['JOB_TITLE_SUBGROUP'],
                       columns=['WORK_STATE'], 
                       aggfunc=np.mean)
sal_table
# Out:
# WORK_STATE                   Alabama        Alaska       Arizona  \
# JOB_TITLE_SUBGROUP
# assistant professor     67132.915593  69666.075667  70865.538019
# attorney               108428.581818           NaN  76838.142857
# business analyst        51913.014286  57530.555556  61154.893401
# data analyst            59283.333333           NaN  63209.753333
# data scientist                   NaN           NaN  73558.111111
# management consultant   87818.000000           NaN  75127.288889
# software engineer       66635.552213  61902.400000  70852.987910
# teacher                 40311.111111  44282.616667  34631.098494
#
# WORK_STATE                 Arkansas     California      Colorado  \
# JOB_TITLE_SUBGROUP
# assistant professor    83075.472727   60126.866613  53044.828155
# attorney                        NaN  116417.301709  77609.222222
# business analyst       48765.209804   70997.609220  64975.383756
# data analyst           48981.200000   71625.793509  58624.766667
# ...

# %%
sal_table.query('JOB_TITLE_SUBGROUP == ["data analyst", "data scientist"]')
# Out:
# WORK_STATE               Alabama  Alaska       Arizona  Arkansas  \
# JOB_TITLE_SUBGROUP
# data analyst        59283.333333     NaN  63209.753333   48981.2
# data scientist               NaN     NaN  73558.111111   55005.5
#
# WORK_STATE             California      Colorado   Connecticut      Delaware  \
# JOB_TITLE_SUBGROUP
# data analyst         71625.793509  58624.766667  65068.721739  70197.721569
# data scientist      100919.876615  65066.666667  91111.333333           NaN
#
# WORK_STATE          District of Columbia       Florida  ...  Tennessee  \
# JOB_TITLE_SUBGROUP                                      ...
# data analyst                65895.904762  53560.607317  ...    48728.8
# data scientist              86580.125000  60548.571429  ...    67163.2
#
# WORK_STATE                 Texas          Utah  Vermont  Virgin Islands  \
# JOB_TITLE_SUBGROUP
# data analyst        58958.776240  45971.366667  31574.0             NaN
# ...

# %%
mal_table = pd.pivot_table(salary_data, 
                       values='PREVAILING_WAGE_PER_YEAR', 
                       index=['WORK_STATE','JOB_TITLE_SUBGROUP'],
                    
                       aggfunc=np.mean)
mal_table
# Out:
#                                   PREVAILING_WAGE_PER_YEAR
# WORK_STATE JOB_TITLE_SUBGROUP
# Alabama    assistant professor                67132.915593
#            attorney                          108428.581818
#            business analyst                   51913.014286
#            data analyst                       59283.333333
#            management consultant              87818.000000
# ...                                                    ...
# Wyoming    assistant professor                52945.961538
#            attorney                           49026.000000
#            business analyst                   49438.000000
#            software engineer                  54600.000000
#            teacher                            47389.600000
#
# [370 rows x 1 columns]

# %%
mal_table.query('JOB_TITLE_SUBGROUP == ["data analyst"]').sort_values(by=['PREVAILING_WAGE_PER_YEAR'], ascending = False)
# Out:
#                                          PREVAILING_WAGE_PER_YEAR
# WORK_STATE           JOB_TITLE_SUBGROUP
# New Hampshire        data analyst                    73413.500000
# California           data analyst                    71625.793509
# Delaware             data analyst                    70197.721569
# Kansas               data analyst                    66005.333333
# District of Columbia data analyst                    65895.904762
# Washington           data analyst                    65502.936508
# Connecticut          data analyst                    65068.721739
# Virginia             data analyst                    64344.778698
# Michigan             data analyst                    64116.145205
# Minnesota            data analyst                    63869.322927
# New Jersey           data analyst                    63539.257143
# Arizona              data analyst                    63209.753333
# Maine                data analyst                    63117.625000
# ...
